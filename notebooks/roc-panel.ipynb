# %%
import pandas as pd
from sklearn import metrics
from operator import itemgetter

from IPython.display import display

# %%
df = pd.read_csv('/mnt/isilon/cbmi/variome/perry/projects/sarmadi/mahdi_epi/work/roc_df_panel/ccr-vest-fathmm-missense_badness-missense_depletion-is_domain', sep='\t')
df.head()
# Out:
#    # of probands      Disease PredictionStatus   Total  Unique alt      ccr  \
# 0         2607.0  Rasopathies    CorrectBenign  3028.0    42.0   A   0.0000
# 1         2607.0  Rasopathies    CorrectBenign  3028.0    42.0   T   0.0000
# 2         2607.0  Rasopathies    CorrectBenign  3028.0    42.0   C   0.0000
# 3         2607.0  Rasopathies      CorrectPath  3028.0    42.0   T  93.2983
# 4         2607.0  Rasopathies      WrongBenign  3028.0    42.0   C  80.9151
#
#    chrom class                   clin_class  \
# 0     19     B      Likely Benign (CFC, NS)
# 1     19     B                Likely Benign
# 2     19     B                Likely benign
# 3     19     P  Likely Pathogenic (CFC, NS)
# 4     19     B                Likely Benign
#
#                                     ...                                    \
# 0                                   ...
# 1                                   ...
# 2                                   ...
# 3                                   ...
# 4                                   ...
#
#   is_domain  missense_badness  missense_depletion  \
# 0         1            0.3769             -0.7469
# 1         1            0.1612             -0.7469
# 2         1            0.1875             -0.7469
# 3         1            0.4756             -0.7469
# 4         0            0.3377             -0.7469
#
#                                              pfam      pos ref   vest  y  \
# 0                                    Pkinase:1640  4099225   G  0.597  0
# 1                                    Pkinase:1640  4099334   C  0.099  0
# 2  Pkinase_Tyr:1074,Pkinase:1641,Pkinase_Tyr:1075  4101064   T  0.544  0
# 3  Pkinase_Tyr:1074,Pkinase:1641,Pkinase_Tyr:1075  4101103   C  0.895  1
# 4                                       none56296  4123824   T  0.121  0
#
#    ccr-vest-fathmm-missense_badness-missense_depletion-is_domain_pred_lm  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  1
# 4                                                  1
#
#   ccr-vest-fathmm-missense_badness-missense_depletion-is_domain_probaPred
# 0                                           0.286155
# 1                                           0.288182
# 2                                           0.294391
# 3                                           1.000000
# 4                                           1.000000
#
# [5 rows x 26 columns]

# %%
auc_ls = []
scores = []
feats = ['ccr', 'vest', 'fathmm', 'missense_badness', 'missense_depletion']
def eval_roc(df, disease):
    scores = [x for x in df.columns.values if '_probaPred' in x or x in feats]
    for score in scores:
        fpr, tpr, _ = metrics.roc_curve(df['y'], df[score], pos_label=1)
        auc = metrics.auc(fpr, tpr)
        avg_pr = metrics.average_precision_score(df['y'], df[score])
        auc_ls.append((auc, avg_pr, score, disease))

diseases = set(df['Disease'])
#with open('roc_eval', 'w') as fout:
#    print('disease\tfpr\ttpr\tfeature', file=fout)
for dis in diseases:
    eval_roc(df[dis==df.Disease], dis)
auc_df = pd.DataFrame(auc_ls, columns=['auc', 'avg_pr', 'features', 'disease'])
#sorted(auc_ls, key=itemgetter(0))

# %%
for disease in diseases:
    display( auc_df[auc_df.disease==disease].sort_values(by='avg_pr', ascending=False) )
# Out:
#         auc    avg_pr                                           features  \
# 5  0.969405  0.966129  ccr-vest-fathmm-missense_badness-missense_depl...
# 0  0.892630  0.914689                                                ccr
# 4  0.934586  0.912911                                               vest
# 1  0.843814  0.778806                                             fathmm
# 3  0.774805  0.768908                                 missense_depletion
# 2  0.663953  0.609898                                   missense_badness
#
#   disease
# 5     EPI
# 0     EPI
# 4     EPI
# 1     EPI
# 3     EPI
# 2     EPI
#          auc    avg_pr                                           features  \
# 6   0.948013  0.968505                                                ccr
# 11  0.942918  0.957517  ccr-vest-fathmm-missense_badness-missense_depl...
# 10  0.903606  0.928870                                               vest
# 9   0.774413  0.838421                                 missense_depletion
# 7   0.847233  0.824411                                             fathmm
# 8   0.677728  0.772449                                   missense_badness
#
#                  disease
# 6   genedx-epi-limitGene
# 11  genedx-epi-limitGene
# 10  genedx-epi-limitGene
# 9   genedx-epi-limitGene
# 7   genedx-epi-limitGene
# 8   genedx-epi-limitGene
#          auc    avg_pr                                           features  \
# 17  0.962892  0.869609  ccr-vest-fathmm-missense_badness-missense_depl...
# 15  0.956506  0.809572                                 missense_depletion
# 12  0.902169  0.801626                                                ccr
# 16  0.840361  0.459964                                               vest
# 13  0.844699  0.394449                                             fathmm
# 14  0.610602  0.233763                                   missense_badness
#
#            disease
# 17  Cardiomyopathy
# 15  Cardiomyopathy
# 12  Cardiomyopathy
# 16  Cardiomyopathy
# 13  Cardiomyopathy
# 14  Cardiomyopathy
#          auc    avg_pr                                           features  \
# 18  0.882353  0.922670                                                ccr
# 22  0.882353  0.899949                                               vest
# 23  0.894118  0.833916  ccr-vest-fathmm-missense_badness-missense_depl...
# 21  0.768627  0.732618                                 missense_depletion
# 19  0.670588  0.713709                                             fathmm
# 20  0.768627  0.708965                                   missense_badness
#
#         disease
# 18  Rasopathies
# 22  Rasopathies
# 23  Rasopathies
# 21  Rasopathies
# 19  Rasopathies
# 20  Rasopathies
