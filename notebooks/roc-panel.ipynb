# %%
import pandas as pd
from sklearn import metrics
from operator import itemgetter

from IPython.display import display

# %%
df = pd.read_csv('/mnt/isilon/cbmi/variome/perry/projects/sarmadi/mahdi_epi/work/panel.roc_df_combo', sep='\t')
df.head()
# Out:
#    chrom       pos alt      ccr  y         Disease   vest  fathmm  \
# 0     14  23883032   G   0.0000  1  Cardiomyopathy  0.943   -1.66
# 1     14  23883041   C  80.3238  1  Cardiomyopathy  0.614   -1.73
# 2     14  23885257   T   0.0000  0  Cardiomyopathy  0.680   -1.79
# 3     14  23887607   T   0.0000  0  Cardiomyopathy  0.108   -1.70
# 4     14  23894130   T  98.7377  1  Cardiomyopathy  0.690   -1.66
#
#    missense_badness  missense_depletion  \
# 0            0.7499              0.6516
# 1            0.3615              0.6516
# 2            0.3248              0.6516
# 3            0.4991              0.6516
# 4            0.3248              0.4409
#
#    ccr-vest-fathmm-missense_badness-missense_depletion-is_domain_pred_lm
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  1

# %%
auc_ls = []
def eval_roc(df, disease):
    scores = [x for x in df.columns.values if not x in ('chrom', 'pos', 'alt', 'Disease', 'y')]
    for score in scores:
        fpr, tpr, _ = metrics.roc_curve(df['y'], df[score], pos_label=1)
        auc = metrics.auc(fpr, tpr)
        avg_pr = metrics.average_precision_score(df['y'], df[score])
        auc_ls.append((auc, avg_pr, score, disease))

diseases = set(df['Disease'])
#with open('roc_eval', 'w') as fout:
#    print('disease\tfpr\ttpr\tfeature', file=fout)
for dis in diseases:
    eval_roc(df[dis==df.Disease], dis)
auc_df = pd.DataFrame(auc_ls, columns=['auc', 'avg_pr', 'features', 'disease'])
#sorted(auc_ls, key=itemgetter(0))

# %%
for disease in diseases:
    display( auc_df[auc_df.disease==disease].sort_values(by='avg_pr', ascending=False) )
# Out:
#         auc    avg_pr                                           features  \
# 5  0.909323  0.921650  ccr-vest-fathmm-missense_badness-missense_depl...
# 0  0.892630  0.914689                                                ccr
# 1  0.934586  0.912911                                               vest
# 3  0.663953  0.609898                                   missense_badness
# 4  0.225195  0.306255                                 missense_depletion
# 2  0.156186  0.285040                                             fathmm
#
#   disease
# 5     EPI
# 0     EPI
# 1     EPI
# 3     EPI
# 4     EPI
# 2     EPI
#          auc    avg_pr                                           features  \
# 6   0.948013  0.968505                                                ccr
# 11  0.893576  0.939020  ccr-vest-fathmm-missense_badness-missense_depl...
# 7   0.903606  0.928870                                               vest
# 9   0.677728  0.772449                                   missense_badness
# 10  0.225587  0.442821                                 missense_depletion
# 8   0.152767  0.416971                                             fathmm
#
#                  disease
# 6   genedx-epi-limitGene
# 11  genedx-epi-limitGene
# 7   genedx-epi-limitGene
# 9   genedx-epi-limitGene
# 10  genedx-epi-limitGene
# 8   genedx-epi-limitGene
#          auc    avg_pr                                           features  \
# 17  0.853976  0.828325  ccr-vest-fathmm-missense_badness-missense_depl...
# 12  0.902169  0.801626                                                ccr
# 13  0.840361  0.459964                                               vest
# 15  0.610602  0.233763                                   missense_badness
# 14  0.155301  0.075303                                             fathmm
# 16  0.043494  0.069380                                 missense_depletion
#
#            disease
# 17  Cardiomyopathy
# 12  Cardiomyopathy
# 13  Cardiomyopathy
# 15  Cardiomyopathy
# 14  Cardiomyopathy
# 16  Cardiomyopathy
#          auc    avg_pr                                           features  \
# 18  0.882353  0.922670                                                ccr
# 19  0.882353  0.899949                                               vest
# 23  0.782353  0.851103  ccr-vest-fathmm-missense_badness-missense_depl...
# 21  0.768627  0.708965                                   missense_badness
# 20  0.329412  0.425363                                             fathmm
# 22  0.231373  0.374602                                 missense_depletion
#
#         disease
# 18  Rasopathies
# 19  Rasopathies
# 23  Rasopathies
# 21  Rasopathies
# 20  Rasopathies
# 22  Rasopathies
